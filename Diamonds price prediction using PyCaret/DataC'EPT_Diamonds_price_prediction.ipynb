# %%
# installing pycaret
# !pip install pycaret

# %%
import pandas as pd
from pycaret.regression import*

# %%
#loading data
train = pd.read_csv('/content/train.csv.zip')
test = pd.read_csv('/content/test.csv')

# %%
print(train.shape, test.shape)
# Out:
# (25000, 11) (5394, 10)

# %%
train.head(3)
# Out:
#    ID  carat      cut color clarity  depth  table     x     y     z  price
# 0   0   0.72    Ideal     H    VVS1   61.5   57.0  5.74  5.76  3.54   3180
# 1   1   0.40  Premium     F     SI2   59.6   58.0  4.85  4.81  2.88    864
# 2   2   0.76    Ideal     E    VVS1   62.2   55.0  5.86  5.82  3.63   5056

# %%
test.head(3)
# Out:
#       ID  carat    cut color clarity  depth  table     x     y     z
# 0   2714   0.33  Ideal     H     SI1   61.7   55.0  4.43  4.46  2.74
# 1  14653   1.20  Ideal     I     VS2   62.1   57.0  6.78  6.71  4.19
# 2  52760   0.62  Ideal     D     VS1   61.0   57.0  5.51  5.54  3.37

# %%
#preparing the data for modeling
setup(train, target = 'price')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_684d229e_832e_11ea_834a_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_684d229e_832e_11ea_834a_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_684d229e_832e_11ea_834a_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_684d229e_832e_11ea_834a_0242ac1c0002row0_col1" class="data row0 col1" >2630</td>
#             </tr>
#             <tr>
#                         <th id="T_684d229e_832e_11ea_834a_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_684d229e_832e_11ea_834a_0242ac1c0002row1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
#selecting the best model
#FOLD = 10
compare_models()
# Out:
# <style  type="text/css" >
#     #T_212a3102_8330_11ea_834a_0242ac1c0002 th {
#           text-align: left;
#     }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col4 {
#             text-align:  left;
#         }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_212a3102_8330_11ea_834a_0242ac1c0002row0_col6 {
#             background-color:  yellow;
# ...

# %%
#creating bunch of models
xgboost = create_model('xgboost')
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0     421.0522  551055.6452  742.3312  0.9655  0.2288  0.1298
# 1     399.6653  498249.9168  705.8682  0.9655  0.2003  0.1340
# 2     403.6719  530353.2908  728.2536  0.9659  0.1867  0.1296
# 3     384.9531  482751.0965  694.8029  0.9687  0.1722  0.1204
# 4     415.1517  613115.0765  783.0167  0.9591  0.2144  0.1323
# 5     423.8058  596783.1234  772.5174  0.9617  0.2031  0.1334
# 6     415.5305  574742.7434  758.1179  0.9622  0.2018  0.1274
# 7     405.7845  542776.2246  736.7335  0.9661  0.1792  0.1269
# 8     413.5815  558703.6771  747.4648  0.9643  0.2017  0.1261
# 9     402.2411  569059.2948  754.3602  0.9666  0.2231  0.1247
# Mean  408.5438  551759.0089  742.3466  0.9646  0.2011  0.1285
# SD     11.0167   38512.6253   26.0860  0.0027  0.0172  0.0040

# %%
et = create_model('et')
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0     284.3897  322124.6386  567.5603  0.9798  0.0967  0.0716
# 1     278.8752  285532.9021  534.3528  0.9802  0.0995  0.0746
# 2     283.3813  302669.2009  550.1538  0.9806  0.0986  0.0730
# 8     413.2283  564688.7533  751.4578  0.9639  0.1947  0.1264
# 9     403.8203  564455.3565  751.3024  0.9669  0.1995  0.1252
# Mean  408.7299  550321.1800  741.3993  0.9646  0.2092  0.1285
# SD     10.3643   37403.7931   25.4596  0.0027  0.0282  0.0040

# %%
lightgbm = create_model('lightgbm')
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0     295.1310  324134.4475  569.3281  0.9797  0.1062  0.0822
# 1     289.5383  275580.9805  524.9581  0.9809  0.1095  0.0862
# 2     296.7108  306109.5169  553.2716  0.9803  0.1119  0.0873
# 3     285.8622  293330.2741  541.5997  0.9810  0.1090  0.0847
# 4     305.7191  383560.6018  619.3227  0.9744  0.1161  0.0885
# 5     304.9273  335231.1419  578.9915  0.9785  0.1138  0.0883
# 6     298.1396  334875.2824  578.6841  0.9780  0.1091  0.0836
# 7     294.8114  313241.9318  559.6802  0.9804  0.1109  0.0858
# 8     314.1598  393966.0383  627.6671  0.9748  0.1124  0.0862
# 9     303.6811  365009.0785  604.1598  0.9786  0.1095  0.0831
# Mean  298.8681  332503.9294  575.7663  0.9787  0.1108  0.0856
# SD      7.9527   36560.3002   31.5769  0.0023  0.0027  0.0020

# %%
# creating multiple layer stacking from specific models
stacknet = create_stacknet([[catboost,rf], [et, lightgbm]])
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0     278.6364  304351.4215  551.6805  0.9810  0.0965  0.0727
# 1     270.6596  259226.6973  509.1431  0.9821  0.1027  0.0786
# 2     269.6913  261364.4874  511.2382  0.9832  0.0984  0.0749
# 3     271.6022  280667.2922  529.7804  0.9818  0.1012  0.0763
# 4     284.6745  380313.4633  616.6956  0.9746  0.1052  0.0762
# 5     286.8531  311109.2334  557.7717  0.9800  0.1058  0.0781
# 6     295.8116  479284.2169  692.3036  0.9685  0.1095  0.0819
# 7     275.8212  288360.2467  536.9918  0.9820  0.0992  0.0758
# 8     290.2442  334039.1992  577.9612  0.9786  0.0998  0.0751
# 9     284.0320  334675.0396  578.5111  0.9803  0.1003  0.0742
# Mean  280.8026  323339.1298  566.2077  0.9792  0.1019  0.0764
# SD      8.4672   62700.6467   52.4208  0.0043  0.0037  0.0025

# %%
# predict test / hold-out dataset
holdout_pred = predict_model(stacknet)
# Out:
#                 Model       MAE          MSE      RMSE      R2   RMSLE    MAPE
# 0  Stacking Regressor  286.0258  305876.2624  553.0608  0.9808  0.1043  0.0775

# %%
#final predicition
final_pred = predict_model(stacknet, data= test)

# %%
final_pred.head()
# Out:
#       ID  carat    cut color clarity  depth  table     x     y     z      Label
# 0   2714   0.33  Ideal     H     SI1   61.7   55.0  4.43  4.46  2.74   482.7286
# 1  14653   1.20  Ideal     I     VS2   62.1   57.0  6.78  6.71  4.19  5563.4918
# 2  52760   0.62  Ideal     D     VS1   61.0   57.0  5.51  5.54  3.37  2596.7581
# 3  48658   0.34   Good     H     VS2   63.1   56.0  4.41  4.46  2.80   521.2183
# 4  14812   1.20  Ideal     E     SI2   62.5   55.0  6.77  6.84  4.25  6245.6648

# %%
y_pred = pd.DataFrame()
y_pred['ID'] = final_pred['ID']
y_pred['price'] = final_pred.Label
y_pred.to_csv('submission.csv',index=False)
